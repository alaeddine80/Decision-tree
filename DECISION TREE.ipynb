# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
#importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
conda install python-graphviz
# Out:
# ...
# Solving environment: ...working... done
#
#
# Note: you may need to restart the kernel to use updated packages.# All requested packages already installed.

# %%
import graphviz

# %% [markdown]
#  # Reading the dataset

# %%
A=pd.read_csv('titanic1.csv')
A
# Out:
#      Unnamed: 0  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  C  \
# 0             0         0       3    1  22.000000      1      0   7.2500  0
# 1             1         1       1    0  38.000000      1      0  71.2833  1
# 2             2         1       3    0  26.000000      0      0   7.9250  0
# 3             3         1       1    0  35.000000      1      0  53.1000  0
# 4             4         0       3    1  35.000000      0      0   8.0500  0
# ..          ...       ...     ...  ...        ...    ...    ...      ... ..
# 886         886         0       2    1  27.000000      0      0  13.0000  0
# 887         887         1       1    0  19.000000      0      0  30.0000  0
# 888         888         0       3    0  29.699118      1      2  23.4500  0
# 889         889         1       1    1  26.000000      0      0  30.0000  1
# 890         890         0       3    1  32.000000      0      0   7.7500  0
#
#      Q  S Title
# 0    0  1    Mr
# 1    0  0   Mrs
# ...

# %%
A1=A.filter(['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','C','Q','S'])
A1
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  C  Q  S
# 0           0       3    1  22.000000      1      0   7.2500  0  0  1
# 1           1       1    0  38.000000      1      0  71.2833  1  0  0
# 2           1       3    0  26.000000      0      0   7.9250  0  0  1
# 3           1       1    0  35.000000      1      0  53.1000  0  0  1
# 4           0       3    1  35.000000      0      0   8.0500  0  0  1
# ..        ...     ...  ...        ...    ...    ...      ... .. .. ..
# 886         0       2    1  27.000000      0      0  13.0000  0  0  1
# 887         1       1    0  19.000000      0      0  30.0000  0  0  1
# 888         0       3    0  29.699118      1      2  23.4500  0  0  1
# 889         1       1    1  26.000000      0      0  30.0000  1  0  0
# 890         0       3    1  32.000000      0      0   7.7500  0  1  0
#
# [891 rows x 10 columns]

# %% [markdown]
# # Splitting Data

# %%
x=A1[['Pclass','Sex','Age','SibSp','Parch','Fare','C','Q','S']]
y=A1['Survived']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
x_train, x_test, y_train, y_test
# Out:
# (     Pclass  Sex        Age  SibSp  Parch      Fare  C  Q  S
#  57        3    1  28.500000      0      0    7.2292  1  0  0
#  717       2    0  27.000000      0      0   10.5000  0  0  1
#  431       3    0  29.699118      1      0   16.1000  0  0  1
#  633       1    1  29.699118      0      0    0.0000  0  0  1
#  163       3    1  17.000000      0      0    8.6625  0  0  1
#  ..      ...  ...        ...    ...    ...       ... .. .. ..
#  369       1    0  24.000000      0      0   69.3000  1  0  0
#  320       3    1  22.000000      0      0    7.2500  0  0  1
#  527       1    1  29.699118      0      0  221.7792  0  0  1
#  125       3    1  12.000000      1      0   11.2417  1  0  0
#  265       2    1  36.000000      0      0   10.5000  0  0  1
#
#  [712 rows x 9 columns],
#       Pclass  Sex        Age  SibSp  Parch      Fare  C  Q  S
#  590       3    1  35.000000      0      0    7.1250  0  0  1
#  131       3    1  20.000000      0      0    7.0500  0  0  1
# ...

# %% [markdown]
# # Applying the decision tree

# %% [markdown]
# # Decision Tree

# %%
clf= tree.DecisionTreeClassifier()  
clf.fit(x_train, y_train)   #fitting our model
y_pred=clf.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %% [markdown]
# # plotting the decision tree

# %%
dot_data =tree.export_graphviz(clf,out_file=None)
graph=graphviz.Source(dot_data)
graph.render('A1')
graph

# %% [markdown]
# # changing the parameters

# %%
x1=A1[['Pclass','Sex','Age','SibSp','Parch','Fare','C','Q','S']]
y1=A1['Survived']
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y1, test_size=0.35,random_state=20)
x1_train, x1_test, y1_train, y1_test
# Out:
# (     Pclass  Sex        Age  SibSp  Parch     Fare  C  Q  S
#  398       2    1  23.000000      0      0  10.5000  0  0  1
#  477       3    1  29.000000      1      0   7.0458  0  0  1
#  536       1    1  45.000000      0      0  26.5500  0  0  1
#  673       2    1  31.000000      0      0  13.0000  0  0  1
#  818       3    1  43.000000      0      0   6.4500  0  0  1
#  ..      ...  ...        ...    ...    ...      ... .. .. ..
#  218       1    0  32.000000      0      0  76.2917  1  0  0
#  223       3    1  29.699118      0      0   7.8958  0  0  1
#  271       3    1  25.000000      0      0   0.0000  0  0  1
#  474       3    0  22.000000      0      0   9.8375  0  0  1
#  355       3    1  28.000000      0      0   9.5000  0  0  1
#
#  [579 rows x 9 columns],
#       Pclass  Sex        Age  SibSp  Parch     Fare  C  Q  S
#  347       3    0  29.699118      1      0  16.1000  0  0  1
#  674       2    1  29.699118      0      0   0.0000  0  0  1
# ...

# %%
clf= tree.DecisionTreeClassifier()  
clf.fit(x1_train, y1_train)   #fitting our model
y1_pred=clf.predict(x1_test)   # evaluating our model
print("score:{}".format(accuracy_score(y1_test, y1_pred)))
# Out:
# score:0.7852564102564102

# %%
#After changing the decision tree parameters the accuracy remain the same

# %% [markdown]
# # Random forest

# %%
clf=RandomForestClassifier(n_estimators=150)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8111111111111111

# %% [markdown]
# # changing the number of estimator

# %%
clf=RandomForestClassifier(n_estimators=200)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7916666666666666

# %%
#After changing the number of estimator the accuracy dropped to 0.79
